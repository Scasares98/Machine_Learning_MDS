# %% [markdown]
# # LENDING CLUB
#
# * __Autor_1:__ Gonzalo Carretero Ursúa
# * __Autor_2:__ Sergio Casares Fernández
#
# ### Introduction
#
# Typically, commercial and non-commercial banks are the main lenders for loans. In contrast of those, Lending Club (LC) is a peer-to-peer online lending  platform.  It  is the  world’s largest  marketplace connecting  borrowers and  investors, where consumers and small business owners lower the cost of their credit and enjoy a better experience than traditional bank lending, and investors earn attractive risk-adjusted returns
#
# ## Index:
# * [1. Library import](#first-bullet)
# * [2. Dataset Modification](#second-bullet)
# * [3. A priori observations selection](#third-bullet)
# * [4. Colective and individual dataset division](#fourth-bullet)
# * [5. EDA (Exploratory Data Analisis)](#fifth-bullet)
# * [6. Dataframes convertion](#sixth-bullet)

# %% [markdown]
# <a name= 'first-bullet'></a>
#
# # 1. Library import

# %%
#Basic operations and visualization
import pandas as pd 
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

#Column transformation
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# <a name= 'second-bullet'></a>
#
# # 2. Dataset Modification

# %%
DF = pd.read_csv('Loan_joined.csv', delimiter = ',')
# Out:
# C:\Users\usuario\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,20,60,119,130,131,132,135,136,137,140,146,147,148) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
DF.shape
# Out:
# (884884, 152)

# %% [markdown]
# #### Drop duplicates

# %%
DF = DF.drop_duplicates() 
#There is no duplicates in the dataset

# %% [markdown]
# <a name= 'third-bullet'></a>
#
# # 3. A priori observations selection

# %% [markdown]
# We drop  'Current' and 'nan' observations from the 'loan_status' column, people who haven´t finished their loans don´t give any value to our goal of prediction and they are unrelevant.

# %%
DF.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'In Grace Period', 'Late (31-120 days)',
#        'Late (16-30 days)', 'Charged Off', 'Default', nan], dtype=object)

# %%
DF = DF[DF.loan_status.isin(['Fully Paid', 'In Grace Period', 'Late (31-120 days)',
       'Late (16-30 days)', 'Charged Off', 'Default'])]
DF.shape, DF.loan_status.unique()
# Out:
# ((462191, 152),
#  array(['Fully Paid', 'In Grace Period', 'Late (31-120 days)',
#         'Late (16-30 days)', 'Charged Off', 'Default'], dtype=object))

# %% [markdown]
# ### 3.1.Dummy Conversion

# %%
DF['loan_acceptance'] = DF['loan_status'].map({'Fully Paid':1,
                                               'In Grace Period':0,
                                               'Late (31-120 days)':0,
                                               'Late (16-30 days)':0,
                                               'Charged Off':0,
                                               'Default':0})

print("Current shape of dataset :",DF.shape)
# Out:
# Current shape of dataset : (462191, 153)

# %% [markdown]
# ### 3.2.Observation sampling
#
# In this case, we realize that people who pay represent the 75% of the total observations, meanwhile people who haven´t paid and delayed in their payment represent the 25% of the total observations.
#
# We believe there is no neccesity in either oversampling or undersampling both of the groups due to the fact that a 1:4 proportion is acceptable for this king of data.

# %%
DF.shape[0]
# Out:
# 462191

# %%
DF.loan_acceptance.value_counts() #porcentaje
# Out:
# 1    345520
# 0    116671
# Name: loan_acceptance, dtype: int64

# %%
ax = sn.countplot(x="loan_acceptance", data=DF)

# %% [markdown]
# <a name= 'fourth-bullet'></a>
#
# # 4. Colective and individual dataset division
#
# We have realised that there are two types of applications, individual and joint app, we have realised that there are significant diferences between both groups so we have decided to split the dataset for both cases.

# %% [markdown]
# ### 4.1. Individual

# %%
lista_final = ['loan_acceptance,','acc_now_delinq','acc_open_past_24mths','all_util','annual_inc','avg_cur_bal','bc_util',
             'collections_12_mths_ex_med','delinq_2yrs', 'delinq_amnt','dti','emp_length',
             'il_util','inq_fi','inq_last_12m','inq_last_6mths','int_rate','loan_amnt','max_bal_bc',
             'mo_sin_old_il_acct','mo_sin_rcnt_rev_tl_op','mort_acc','mths_since_last_delinq',
             'mths_since_recent_inq','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl',
             'num_il_tl','num_op_rev_tl','num_rev_accts','num_tl_120dpd_2m','num_tl_30dpd',
             'num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_act_il','percent_bc_gt_75',
             'revol_bal','tax_liens','tot_cur_bal','total_acc','total_bal_ex_mort',
             'total_bc_limit','total_cu_tl','total_rev_hi_lim','MORTGAGE', 'OWN', 'RENT']

# %%
DF_UNO = DF[DF['application_type'] == 'Individual']

lista_ind = ['loan_acceptance','acc_now_delinq','acc_open_past_24mths','all_util','annual_inc','avg_cur_bal','bc_util',
             'collections_12_mths_ex_med','delinq_2yrs', 'delinq_amnt','dti','emp_length','home_ownership',
             'il_util','inq_fi','inq_last_12m','inq_last_6mths','installment','int_rate','loan_amnt','max_bal_bc',
             'mo_sin_old_il_acct','mo_sin_rcnt_rev_tl_op','mort_acc','mths_since_last_delinq',
             'mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq',
             'num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl',
             'num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd',
             'num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_act_il','percent_bc_gt_75','revol_bal',
             'tax_liens','tot_cur_bal','tot_hi_cred_lim','total_acc','total_bal_ex_mort','total_bal_il',
             'total_bc_limit','total_cu_tl','total_rev_hi_lim']
df_ind = DF_UNO[lista_ind]
df_ind.shape
# Out:
# (460541, 54)

# %%
#DF con solo las primeras 500 observaciones
mini_df_ind = df_ind.iloc[0:5000,]
mini_df_ind.shape
# Out:
# (5000, 54)

# %% [markdown]
# ### 4.2. Joint-App

# %%
DF_VARIOS = DF[DF['application_type'] == 'Joint App']
lista_col = ['loan_acceptance','acc_now_delinq','acc_open_past_24mths','all_util','annual_inc_joint','avg_cur_bal',
             'bc_util','collections_12_mths_ex_med','delinq_2yrs','delinq_amnt','dti_joint',
             'emp_length','home_ownership','il_util','inq_fi','inq_last_12m','inq_last_6mths',
             'installment','int_rate','loan_amnt','max_bal_bc','mo_sin_old_il_acct','mo_sin_rcnt_rev_tl_op',
             'mort_acc','mths_since_last_delinq','mths_since_recent_bc_dlq','mths_since_recent_inq',
             'mths_since_recent_revol_delinq','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl',
             'num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m',
             'num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_act_il',
             'percent_bc_gt_75','revol_bal','tax_liens','tot_cur_bal','tot_hi_cred_lim','total_acc',
             'total_bal_ex_mort','total_bal_il','total_bc_limit','total_cu_tl','total_rev_hi_lim',
             'revol_bal_joint' ,'sec_app_fico_range_low','sec_app_fico_range_high',
             'sec_app_earliest_cr_line' ,'sec_app_inq_last_6mths' ,'sec_app_mort_acc' ,'sec_app_open_acc' ,
             'sec_app_revol_util' ,'sec_app_open_act_il','sec_app_num_rev_accts' ,'sec_app_chargeoff_within_12_mths',
             'sec_app_collections_12_mths_ex_med' ,'sec_app_mths_since_last_major_derog']
df_joint = DF_VARIOS[lista_col]
df_joint.shape
# Out:
# (1650, 67)

# %%
mini_df_joint = df_joint.iloc[0:5000,]
mini_df_joint.shape
# Out:
# (1650, 67)

# %% [markdown]
# <a name= 'fifth-bullet'></a>
#
# # 5. EDA (Exploratory Data Analisis)

# %% [markdown]
# Let´s begin with the Exploratory Data Analisis of our dataset for all the observations and the variables selected.

# %%
df_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460541 entries, 8 to 884881
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   loan_acceptance                 460541 non-null  int64
#  1   acc_now_delinq                  460541 non-null  float64
#  2   acc_open_past_24mths            460541 non-null  float64
#  3   all_util                        29866 non-null   float64
#  4   annual_inc                      460541 non-null  float64
#  5   avg_cur_bal                     460535 non-null  float64
#  6   bc_util                         455373 non-null  float64
#  7   collections_12_mths_ex_med      460541 non-null  float64
#  8   delinq_2yrs                     460541 non-null  float64
#  9   delinq_amnt                     460541 non-null  float64
#  10  dti                             460541 non-null  float64
#  11  emp_length                      435708 non-null  object
#  12  home_ownership                  460541 non-null  object
#  13  il_util                         26097 non-null   float64
#  14  inq_fi                          29869 non-null   float64
#  15  inq_last_12m                    29869 non-null   float64
#  16  inq_last_6mths                  460541 non-null  float64
#  17  installment                     460541 non-null  float64
#  18  int_rate                        460541 non-null  object
#  19  loan_amnt                       460541 non-null  float64
#  20  max_bal_bc                      29869 non-null   float64
#  21  mo_sin_old_il_acct              447350 non-null  float64
#  22  mo_sin_rcnt_rev_tl_op           460541 non-null  float64
#  23  mort_acc                        460541 non-null  float64
#  24  mths_since_last_delinq          237195 non-null  float64
#  25  mths_since_recent_bc_dlq        121269 non-null  float64
#  26  mths_since_recent_inq           420213 non-null  float64
#  27  mths_since_recent_revol_delinq  166404 non-null  float64
#  28  num_actv_bc_tl                  460541 non-null  float64
#  29  num_actv_rev_tl                 460541 non-null  float64
#  30  num_bc_sats                     460541 non-null  float64
#  31  num_bc_tl                       460541 non-null  float64
#  32  num_il_tl                       460541 non-null  float64
#  33  num_op_rev_tl                   460541 non-null  float64
#  34  num_rev_accts                   460540 non-null  float64
#  35  num_rev_tl_bal_gt_0             460541 non-null  float64
#  36  num_sats                        460541 non-null  float64
#  37  num_tl_120dpd_2m                441206 non-null  float64
#  38  num_tl_30dpd                    460541 non-null  float64
#  39  num_tl_90g_dpd_24m              460541 non-null  float64
#  40  num_tl_op_past_12m              460541 non-null  float64
#  41  open_acc                        460541 non-null  float64
#  42  open_act_il                     29869 non-null   float64
#  43  percent_bc_gt_75                455428 non-null  float64
#  44  revol_bal                       460541 non-null  float64
#  45  tax_liens                       460541 non-null  float64
#  46  tot_cur_bal                     460541 non-null  float64
#  47  tot_hi_cred_lim                 460541 non-null  float64
#  48  total_acc                       460541 non-null  float64
#  49  total_bal_ex_mort               460541 non-null  float64
#  50  total_bal_il                    29869 non-null   float64
#  51  total_bc_limit                  460541 non-null  float64
#  52  total_cu_tl                     29869 non-null   float64
#  53  total_rev_hi_lim                460541 non-null  float64
# dtypes: float64(50), int64(1), object(3)
# memory usage: 193.3+ MB

# %% [markdown]
# ## 5.1.Categorical Variables

# %% [markdown]
# * emp_length
# * home_ownership
# * int_rate

# %%
ax = sn.countplot(y="emp_length", data=df_ind)

# %%
ax = sn.countplot(y="home_ownership", data=df_ind)

# %%
ax = sn.countplot(y="int_rate", data=df_ind)

# %% [markdown]
# Posteriormente en la ingeniería de variables, modificaremos dichas variables y se convertirán en numéricas.

# %% [markdown]
# ## 5.2. Variable engineering
#
# Now, for the goal of predict, we are going to transform the categorical variables in numerical for two purposes, realize a better EDA and use this variables in our predictions.

# %% [markdown]
# ### __emp_length__

# %%
def años_casa(x):
    if x == '< 1 year':
        return '0'
    elif x == '1 year':
        return '1'
    elif x == '2 years':
        return '2'
    elif x == '3 years':
        return '3'
    elif x == '4 years':
        return '4'
    elif x == '5 years':
        return '5'
    elif x == '6 years':
        return '6'
    elif x == '7 years':
        return '7'
    elif x == '8 years':
        return '8'
    elif x == '9 years':
        return '9'
    elif x == '10+ years':
        return '10'
    else:
        return '0'
df_ind['emp_length'] = df_ind['emp_length'].map(años_casa)
# Out:
# <ipython-input-11-613ef72dd01c>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ind['emp_length'] = df_ind['emp_length'].map(años_casa)

# %%
df_ind['emp_length'] = pd.to_numeric(df_ind['emp_length'])
# Out:
# <ipython-input-12-71992e1551e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ind['emp_length'] = pd.to_numeric(df_ind['emp_length'])

# %% [markdown]
# ### __home_ownership__

# %%
df_ind.shape
# Out:
# (460541, 54)

# %%
one_hot = pd.get_dummies(df_ind['home_ownership'])
one_hot = one_hot.drop('ANY', axis = 1)
one_hot.shape
# Out:
# (460541, 3)

# %%
df_ind = df_ind.drop(['home_ownership'], axis = 1)

# %%
df_ind = pd.concat([df_ind, one_hot], axis=1)

# %%
df_ind.dtypes
# Out:
# loan_acceptance                     int64
# acc_now_delinq                    float64
# acc_open_past_24mths              float64
# all_util                          float64
# annual_inc                        float64
# avg_cur_bal                       float64
# bc_util                           float64
# collections_12_mths_ex_med        float64
# delinq_2yrs                       float64
# delinq_amnt                       float64
# dti                               float64
# emp_length                          int64
# il_util                           float64
# inq_fi                            float64
# inq_last_12m                      float64
# inq_last_6mths                    float64
# installment                       float64
# int_rate                           object
# loan_amnt                         float64
# max_bal_bc                        float64
# mo_sin_old_il_acct                float64
# mo_sin_rcnt_rev_tl_op             float64
# mort_acc                          float64
# mths_since_last_delinq            float64
# mths_since_recent_bc_dlq          float64
# mths_since_recent_inq             float64
# mths_since_recent_revol_delinq    float64
# num_actv_bc_tl                    float64
# num_actv_rev_tl                   float64
# num_bc_sats                       float64
# num_bc_tl                         float64
# num_il_tl                         float64
# num_op_rev_tl                     float64
# num_rev_accts                     float64
# num_rev_tl_bal_gt_0               float64
# num_sats                          float64
# num_tl_120dpd_2m                  float64
# num_tl_30dpd                      float64
# num_tl_90g_dpd_24m                float64
# num_tl_op_past_12m                float64
# open_acc                          float64
# open_act_il                       float64
# percent_bc_gt_75                  float64
# revol_bal                         float64
# tax_liens                         float64
# tot_cur_bal                       float64
# tot_hi_cred_lim                   float64
# total_acc                         float64
# total_bal_ex_mort                 float64
# total_bal_il                      float64
# total_bc_limit                    float64
# total_cu_tl                       float64
# total_rev_hi_lim                  float64
# MORTGAGE                            uint8
# OWN                                 uint8
# RENT                                uint8
# dtype: object

# %% [markdown]
# ### __int_rate__

# %%
df_ind['int_rate'] = list(map(lambda x : x[:-1], df_ind.int_rate))
df_ind['int_rate'] = pd.to_numeric(df_ind['int_rate'])

# %% [markdown]
# ## 5.3 Numerical variables analisis

# %%
df_ind.describe()
# Out:
#        loan_acceptance  acc_now_delinq  acc_open_past_24mths      all_util  \
# count    460541.000000   460541.000000         460541.000000  29866.000000
# mean          0.748266        0.005743              4.809046     58.576441
# std           0.434010        0.081564              3.157228     21.332408
# min           0.000000        0.000000              0.000000      0.000000
# 25%           0.000000        0.000000              3.000000     45.000000
# 50%           1.000000        0.000000              4.000000     60.000000
# 75%           1.000000        0.000000              6.000000     74.000000
# max           1.000000        6.000000             64.000000    152.000000
#
#          annual_inc    avg_cur_bal        bc_util  collections_12_mths_ex_med  \
# count  4.605410e+05  460535.000000  455373.000000               460541.000000
# mean   7.569814e+04   13213.683175      61.878678                    0.018487
# std    6.612132e+04   15939.265727      27.664251                    0.152629
# min    3.000000e+03       0.000000       0.000000                    0.000000
# 25%    4.600000e+04    3108.000000      41.200000                    0.000000
# 50%    6.500000e+04    7250.000000      65.500000                    0.000000
# 75%    9.000000e+04   18275.000000      86.100000                    0.000000
# max    9.500000e+06  497484.000000     255.200000                   20.000000
#
#          delinq_2yrs    delinq_amnt  ...  tot_hi_cred_lim      total_acc  \
# count  460541.000000  460541.000000  ...     4.605410e+05  460541.000000
# mean        0.342834      13.006115  ...     1.707151e+05      25.997553
# std         0.917235     716.563057  ...     1.734529e+05      12.159159
# min         0.000000       0.000000  ...     0.000000e+00       2.000000
# 25%         0.000000       0.000000  ...     4.882800e+04      17.000000
# 50%         0.000000       0.000000  ...     1.095740e+05      24.000000
# 75%         0.000000       0.000000  ...     2.467910e+05      33.000000
# max        39.000000   94521.000000  ...     9.999999e+06     169.000000
#
#        total_bal_ex_mort   total_bal_il  total_bc_limit   total_cu_tl  \
# count       4.605410e+05   29869.000000   460541.000000  29869.000000
# mean        4.980020e+04   36989.817871    20512.291075      1.730657
# std         4.717592e+04   43163.800703    20800.817506      2.909695
# min         0.000000e+00       0.000000        0.000000      0.000000
# 25%         2.133800e+04   10659.000000     7100.000000      0.000000
# 50%         3.769600e+04   25080.000000    14100.000000      1.000000
# 75%         6.268800e+04   48100.000000    26600.000000      2.000000
# max         2.688920e+06  634217.000000   760000.000000     68.000000
#
#        total_rev_hi_lim       MORTGAGE            OWN           RENT
# count      4.605410e+05  460541.000000  460541.000000  460541.000000
# mean       3.157871e+04       0.495311       0.104201       0.400483
# std        3.551501e+04       0.499979       0.305522       0.489997
# min        0.000000e+00       0.000000       0.000000       0.000000
# 25%        1.350000e+04       0.000000       0.000000       0.000000
# 50%        2.310000e+04       0.000000       0.000000       0.000000
# 75%        3.920000e+04       1.000000       0.000000       1.000000
# max        9.999999e+06       1.000000       1.000000       1.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# ### 5.3.1 Pipeline scalation and imputation

# %%
lista_final = ['loan_acceptance','acc_now_delinq','acc_open_past_24mths','all_util','annual_inc','avg_cur_bal','bc_util',
             'collections_12_mths_ex_med','delinq_2yrs', 'delinq_amnt','dti','emp_length',
             'il_util','inq_fi','inq_last_12m','inq_last_6mths','int_rate','loan_amnt','max_bal_bc',
             'mo_sin_old_il_acct','mo_sin_rcnt_rev_tl_op','mort_acc','mths_since_last_delinq',
             'mths_since_recent_inq','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl',
             'num_il_tl','num_op_rev_tl','num_rev_accts','num_tl_120dpd_2m','num_tl_30dpd',
             'num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_act_il','percent_bc_gt_75',
             'revol_bal','tax_liens','tot_cur_bal','total_acc','total_bal_ex_mort',
             'total_bc_limit','total_cu_tl','total_rev_hi_lim','MORTGAGE', 'OWN', 'RENT']

df_ind = df_ind[lista_final]
df_ind.shape
# Out:
# (460541, 49)

# %% [markdown]
# ## Y

# %%
loan_acceptance_df = df_ind['loan_acceptance']
loan_acceptance_df = pd.DataFrame(loan_acceptance_df)
loan_acceptance_df.reset_index(drop=True, inplace=True)
loan_acceptance_df.head(10)
# Out:
#    loan_acceptance
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# 5                1
# 6                0
# 7                1
# 8                0
# 9                1

# %%
#Guardamos Y
#df_ind_esc.to_csv('Y.csv')

# %%
#del df_ind['loan_acceptance']

# %%
df_ind_xd = df_ind.drop(['loan_acceptance'], axis = 1)
df_ind_xd.reset_index(drop=True, inplace=True)
df_ind_xd.head()
# Out:
#    acc_now_delinq  acc_open_past_24mths  all_util  annual_inc  avg_cur_bal  \
# 0             0.0                   8.0      36.0    153000.0      23302.0
# 1             0.0                   2.0      74.0     50000.0       1863.0
# 2             0.0                  13.0      39.0    110000.0      14551.0
# 3             0.0                   7.0      32.0     51979.0        730.0
# 4             0.0                   5.0      83.0     75000.0      31911.0
#
#    bc_util  collections_12_mths_ex_med  delinq_2yrs  delinq_amnt    dti  ...  \
# 0     13.6                         0.0          0.0          0.0  16.99  ...
# 1     98.9                         0.0          0.0          0.0   6.07  ...
# 2     27.9                         0.0          0.0          0.0  13.12  ...
# 3     22.2                         0.0          0.0          0.0  10.11  ...
# 4     90.0                         0.0          1.0          0.0  10.86  ...
#
#    tax_liens  tot_cur_bal  total_acc  total_bal_ex_mort  total_bc_limit  \
# 0        0.0     442731.0       46.0           100865.0         28100.0
# 1        0.0       5588.0        5.0             5588.0          3600.0
# 2        0.0     276461.0       27.0            45955.0         83700.0
# 3        0.0      10956.0       21.0            10956.0         18800.0
# 4        0.0     127645.0       10.0            27684.0          3000.0
#
#    total_cu_tl  total_rev_hi_lim  MORTGAGE  OWN  RENT
# 0          6.0           37600.0         0    1     0
# 1          0.0            3600.0         0    0     1
# 2          8.0           85700.0         1    0     0
# 3          0.0           28700.0         0    0     1
# 4          0.0            3000.0         1    0     0
#
# [5 rows x 48 columns]

# %%
df_ind_xd.head()
# Out:
#    acc_now_delinq  acc_open_past_24mths  all_util  annual_inc  avg_cur_bal  \
# 0             0.0                   8.0      36.0    153000.0      23302.0
# 1             0.0                   2.0      74.0     50000.0       1863.0
# 2             0.0                  13.0      39.0    110000.0      14551.0
# 3             0.0                   7.0      32.0     51979.0        730.0
# 4             0.0                   5.0      83.0     75000.0      31911.0
#
#    bc_util  collections_12_mths_ex_med  delinq_2yrs  delinq_amnt    dti  ...  \
# 0     13.6                         0.0          0.0          0.0  16.99  ...
# 1     98.9                         0.0          0.0          0.0   6.07  ...
# 2     27.9                         0.0          0.0          0.0  13.12  ...
# 3     22.2                         0.0          0.0          0.0  10.11  ...
# 4     90.0                         0.0          1.0          0.0  10.86  ...
#
#    tax_liens  tot_cur_bal  total_acc  total_bal_ex_mort  total_bc_limit  \
# 0        0.0     442731.0       46.0           100865.0         28100.0
# 1        0.0       5588.0        5.0             5588.0          3600.0
# 2        0.0     276461.0       27.0            45955.0         83700.0
# 3        0.0      10956.0       21.0            10956.0         18800.0
# 4        0.0     127645.0       10.0            27684.0          3000.0
#
#    total_cu_tl  total_rev_hi_lim  MORTGAGE  OWN  RENT
# 0          6.0           37600.0         0    1     0
# 1          0.0            3600.0         0    0     1
# 2          8.0           85700.0         1    0     0
# 3          0.0           28700.0         0    0     1
# 4          0.0            3000.0         1    0     0
#
# [5 rows x 48 columns]

# %%
transformador_numerico = Pipeline(steps=[
    
    ('imputador', SimpleImputer(strategy = 'median')),
    
    ('escalador', StandardScaler())
    
])

# %%
df_ind_esc = transformador_numerico.fit_transform(df_ind_xd)
df_ind_esc = pd.DataFrame(df_ind_esc)

# %%
lista_ind_1 = ['acc_now_delinq','acc_open_past_24mths','all_util','annual_inc','avg_cur_bal','bc_util',
             'collections_12_mths_ex_med','delinq_2yrs', 'delinq_amnt','dti','emp_length',
             'il_util','inq_fi','inq_last_12m','inq_last_6mths','int_rate','loan_amnt','max_bal_bc',
             'mo_sin_old_il_acct','mo_sin_rcnt_rev_tl_op','mort_acc','mths_since_last_delinq',
             'mths_since_recent_inq',
             'num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl',
             'num_rev_accts','num_tl_120dpd_2m','num_tl_30dpd',
             'num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_act_il','percent_bc_gt_75','revol_bal',
             'tax_liens','tot_cur_bal','total_acc','total_bal_ex_mort',
             'total_bc_limit','total_cu_tl','total_rev_hi_lim','MORTGAGE', 'OWN', 'RENT']
df_ind_esc.columns = [lista_ind_1]
df_ind_esc.head(10)
# Out:
#   acc_now_delinq acc_open_past_24mths  all_util annual_inc avg_cur_bal  \
# 0      -0.070414             1.010683 -4.391856   1.169092    0.632931
# 1      -0.070414            -0.889720  2.588767  -0.388652   -0.712121
# 2      -0.070414             2.594353 -3.840754   0.518772    0.083906
# 3      -0.070414             0.693949 -5.126658  -0.358722   -0.783204
# 4      -0.070414             0.060482  4.242073  -0.010558    1.173048
# 5      -0.070414             0.060482 -3.289652   1.274959   -0.699322
# 6      -0.070414            -0.256252  4.425773  -0.645755   -0.663749
# 7      -0.070414            -0.889720  0.935462  -0.192043    1.385794
# 8      -0.070414            -0.572986  7.364983   0.140679   -0.344724
# 9      -0.070414            -0.572986  0.016959  -0.570137    0.288371
#
#     bc_util collections_12_mths_ex_med delinq_2yrs delinq_amnt       dti  ...  \
# 0 -1.756350                  -0.121123   -0.373769   -0.018151 -0.168370  ...
# 1  1.344204                  -0.121123   -0.373769   -0.018151 -1.473418  ...
# 2 -1.236562                  -0.121123   -0.373769   -0.018151 -0.630874  ...
# 3 -1.443750                  -0.121123   -0.373769   -0.018151 -0.990598  ...
# 4  1.020700                  -0.121123    0.716465   -0.018151 -0.900966  ...
# 5 -0.883978                  -0.121123   -0.373769   -0.018151 -1.351518  ...
# 6  1.246062                  -0.121123   -0.373769   -0.018151  1.664912  ...
# 7  0.958907                  -0.121123   -0.373769   -0.018151 -0.216174  ...
# 8  1.384188                  -0.121123    0.716465   -0.018151 -0.450414  ...
# 9 -1.076627                  -0.121123    0.716465    1.427641  0.024041  ...
#
#   tax_liens tot_cur_bal total_acc total_bal_ex_mort total_bc_limit  \
# 0 -0.136687    1.966093  1.645054          1.082435       0.364780
# 1 -0.136687   -0.865215 -1.726894         -0.937178      -0.813060
# 2 -0.136687    0.889188  0.082444         -0.081508       3.037755
# 3 -0.136687   -0.830447 -0.411012         -0.823391      -0.082319
# 4 -0.136687   -0.074671 -1.315681         -0.468803      -0.841905
# 5 -0.136687   -0.727349  0.822627         -0.485973       0.283052
# 6 -0.136687   -0.730795 -0.575497         -0.497250      -0.639990
# 7 -0.136687    1.156410 -0.739982         -0.331657      -0.563069
# 8 -0.136687   -0.701416 -1.315681         -0.233810      -0.440478
# 9 -0.136687    0.136760 -0.822225         -0.625303      -0.514994
#
#   total_cu_tl total_rev_hi_lim  MORTGAGE       OWN      RENT
# 0    6.494958         0.169542 -0.990665  2.932031 -0.817319
# 1   -1.373566        -0.787800 -0.990665 -0.341061  1.223512
# 2    9.117799         1.523901  1.009422 -0.341061 -0.817319
# 3   -1.373566        -0.081056 -0.990665 -0.341061  1.223512
# 4   -1.373566        -0.804695  1.009422 -0.341061 -0.817319
# 5   -1.373566         0.476455  1.009422 -0.341061 -0.817319
# 6   -0.062145        -0.638568 -0.990665 -0.341061  1.223512
# 7   -1.373566        -0.345733 -0.990665  2.932031 -0.817319
# 8    2.560696        -0.569583 -0.990665 -0.341061  1.223512
# 9   -0.062145        -0.486519  1.009422 -0.341061 -0.817319
#
# [10 rows x 48 columns]

# %%
#Guardamos X
#df_ind_esc.to_csv('X.csv')

# %%
#Unimos datasets
df_ind_esc = pd.concat([loan_acceptance_df, df_ind_esc], axis = 1)
df_ind_esc.head(15)
# Out:
#     loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  (all_util,)  \
# 0                 1          -0.070414                 1.010683    -4.391856
# 1                 1          -0.070414                -0.889720     2.588767
# 2                 1          -0.070414                 2.594353    -3.840754
# 3                 1          -0.070414                 0.693949    -5.126658
# 4                 1          -0.070414                 0.060482     4.242073
# 5                 1          -0.070414                 0.060482    -3.289652
# 6                 0          -0.070414                -0.256252     4.425773
# 7                 1          -0.070414                -0.889720     0.935462
# 8                 0          -0.070414                -0.572986     7.364983
# 9                 1          -0.070414                -0.572986     0.016959
# 10                0          -0.070414                -1.206454     3.139869
# 11                1          -0.070414                -0.572986   -11.005077
# 12                1          -0.070414                 0.377215     2.405067
# 13                0          -0.070414                 0.693949     4.425773
# 14                1          -0.070414                 0.060482     4.425773
#
#     (annual_inc,)  (avg_cur_bal,)  (bc_util,)  (collections_12_mths_ex_med,)  \
# 0        1.169092        0.632931   -1.756350                      -0.121123
# 1       -0.388652       -0.712121    1.344204                      -0.121123
# 2        0.518772        0.083906   -1.236562                      -0.121123
# 3       -0.358722       -0.783204   -1.443750                      -0.121123
# 4       -0.010558        1.173048    1.020700                      -0.121123
# 5        1.274959       -0.699322   -0.883978                      -0.121123
# 6       -0.645755       -0.663749    1.246062                      -0.121123
# 7       -0.192043        1.385794    0.958907                      -0.121123
# 8        0.140679       -0.344724    1.384188                      -0.121123
# 9       -0.570137        0.288371   -1.076627                      -0.121123
# 10      -0.615508       -0.696373    1.235158                      -0.121123
# 11       2.636094        5.047091   -2.250694                      -0.121123
# 12       0.140679        0.502874    0.246470                      -0.121123
# 13       5.660840        3.497323    0.729909                      -0.121123
# 14      -0.464270        0.527782    0.457293                      -0.121123
#
#     (delinq_2yrs,)  (delinq_amnt,)  ...  (tax_liens,)  (tot_cur_bal,)  \
# 0        -0.373769       -0.018151  ...     -0.136687        1.966093
# 1        -0.373769       -0.018151  ...     -0.136687       -0.865215
# 2        -0.373769       -0.018151  ...     -0.136687        0.889188
# 3        -0.373769       -0.018151  ...     -0.136687       -0.830447
# 4         0.716465       -0.018151  ...     -0.136687       -0.074671
# 5        -0.373769       -0.018151  ...     -0.136687       -0.727349
# 6        -0.373769       -0.018151  ...     -0.136687       -0.730795
# 7        -0.373769       -0.018151  ...     -0.136687        1.156410
# 8         0.716465       -0.018151  ...     -0.136687       -0.701416
# 9         0.716465        1.427641  ...     -0.136687        0.136760
# 10       -0.373769       -0.018151  ...     -0.136687       -0.860338
# 11        0.716465       -0.018151  ...     -0.136687        3.344930
# 12       -0.373769       -0.018151  ...     -0.136687        0.748543
# 13       -0.373769       -0.018151  ...     -0.136687        5.351457
# 14       -0.373769       -0.018151  ...     -0.136687        0.779425
#
#     (total_acc,)  (total_bal_ex_mort,)  (total_bc_limit,)  (total_cu_tl,)  \
# 0       1.645054              1.082435           0.364780        6.494958
# 1      -1.726894             -0.937178          -0.813060       -1.373566
# 2       0.082444             -0.081508           3.037755        9.117799
# 3      -0.411012             -0.823391          -0.082319       -1.373566
# 4      -1.315681             -0.468803          -0.841905       -1.373566
# 5       0.822627             -0.485973           0.283052       -1.373566
# 6      -0.575497             -0.497250          -0.639990       -0.062145
# 7      -0.739982             -0.331657          -0.563069       -1.373566
# 8      -1.315681             -0.233810          -0.440478        2.560696
# 9      -0.822225             -0.625303          -0.514994       -0.062145
# 10     -1.562408             -0.921217          -0.880365        1.249275
# 11      0.658142              0.821729           2.715651       -0.062145
# 12      1.316083              1.727553           0.182094        1.249275
# 13      1.809539              3.158602           4.460777       -0.062145
# 14     -0.493254              0.071515          -0.067896       -0.062145
#
#     (total_rev_hi_lim,)  (MORTGAGE,)    (OWN,)   (RENT,)
# 0              0.169542    -0.990665  2.932031 -0.817319
# 1             -0.787800    -0.990665 -0.341061  1.223512
# 2              1.523901     1.009422 -0.341061 -0.817319
# 3             -0.081056    -0.990665 -0.341061  1.223512
# 4             -0.804695     1.009422 -0.341061 -0.817319
# 5              0.476455     1.009422 -0.341061 -0.817319
# 6             -0.638568    -0.990665 -0.341061  1.223512
# 7             -0.345733    -0.990665  2.932031 -0.817319
# 8             -0.569583    -0.990665 -0.341061  1.223512
# 9             -0.486519     1.009422 -0.341061 -0.817319
# 10            -0.827220    -0.990665 -0.341061  1.223512
# 11             1.982862     1.009422 -0.341061 -0.817319
# 12             0.020309     1.009422 -0.341061 -0.817319
# 13             6.707630     1.009422 -0.341061 -0.817319
# 14            -0.283788     1.009422 -0.341061 -0.817319
#
# [15 rows x 49 columns]

# %% [markdown]
# ### 5.3.2. Outliers treatment

# %%
df_ind_esc.head(5)
# Out:
#    loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  (all_util,)  \
# 0                1          -0.070414                 1.010683    -4.391856
# 1                1          -0.070414                -0.889720     2.588767
# 2                1          -0.070414                 2.594353    -3.840754
# 3                1          -0.070414                 0.693949    -5.126658
# 4                1          -0.070414                 0.060482     4.242073
#
#    (annual_inc,)  (avg_cur_bal,)  (bc_util,)  (collections_12_mths_ex_med,)  \
# 0       1.169092        0.632931   -1.756350                      -0.121123
# 1      -0.388652       -0.712121    1.344204                      -0.121123
# 2       0.518772        0.083906   -1.236562                      -0.121123
# 3      -0.358722       -0.783204   -1.443750                      -0.121123
# 4      -0.010558        1.173048    1.020700                      -0.121123
#
#    (delinq_2yrs,)  (delinq_amnt,)  ...  (tax_liens,)  (tot_cur_bal,)  \
# 0       -0.373769       -0.018151  ...     -0.136687        1.966093
# 1       -0.373769       -0.018151  ...     -0.136687       -0.865215
# 2       -0.373769       -0.018151  ...     -0.136687        0.889188
# 3       -0.373769       -0.018151  ...     -0.136687       -0.830447
# 4        0.716465       -0.018151  ...     -0.136687       -0.074671
#
#    (total_acc,)  (total_bal_ex_mort,)  (total_bc_limit,)  (total_cu_tl,)  \
# 0      1.645054              1.082435           0.364780        6.494958
# 1     -1.726894             -0.937178          -0.813060       -1.373566
# 2      0.082444             -0.081508           3.037755        9.117799
# 3     -0.411012             -0.823391          -0.082319       -1.373566
# 4     -1.315681             -0.468803          -0.841905       -1.373566
#
#    (total_rev_hi_lim,)  (MORTGAGE,)    (OWN,)   (RENT,)
# 0             0.169542    -0.990665  2.932031 -0.817319
# 1            -0.787800    -0.990665 -0.341061  1.223512
# 2             1.523901     1.009422 -0.341061 -0.817319
# 3            -0.081056    -0.990665 -0.341061  1.223512
# 4            -0.804695     1.009422 -0.341061 -0.817319
#
# [5 rows x 49 columns]

# %% [markdown]
# from scipy import stats
# z = np.abs(stats.zscore(df_ind_esc))
# df_ind_esc_jeje = df_ind_esc[(z < 5).all(axis=1)]
#
#
# df_ind_esc_jeje.shape #(460541, 56)
#
# * Con z > 3, el valor es (326489, 56)
# * Con z > 4, el valor es (387141, 56)
# * Con z > 5, el valor es (411256, 56)
#
# Esto era otra manera, pero te quita muchos valores, por solo un valor extremo de una columna, aunque las otras 56 sean valores normales

# %%
df_ind_esc.describe()
# Out:
#        loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  \
# count    460541.000000       4.605410e+05             4.605410e+05
# mean          0.748266       1.580896e-14            -2.671740e-14
# std           0.434010       1.000001e+00             1.000001e+00
# min           0.000000      -7.041427e-02            -1.523188e+00
# 25%           0.000000      -7.041427e-02            -5.729863e-01
# 50%           1.000000      -7.041427e-02            -2.562524e-01
# 75%           1.000000      -7.041427e-02             3.772154e-01
# max           1.000000       7.349176e+01             1.874778e+01
#
#         (all_util,)  (annual_inc,)  (avg_cur_bal,)    (bc_util,)  \
# count  4.605410e+05   4.605410e+05    4.605410e+05  4.605410e+05
# mean   8.656242e-14  -1.104130e-15    6.741021e-17 -5.295410e-15
# std    1.000001e+00   1.000001e+00    1.000001e+00  1.000001e+00
# min   -1.100508e+01  -1.099467e+00   -8.290027e-01 -2.250694e+00
# 25%    1.695878e-02  -4.491467e-01   -6.340112e-01 -7.422180e-01
# 50%    1.695878e-02  -1.617958e-01   -3.741481e-01  1.301537e-01
# 75%    1.695878e-02   2.162975e-01    3.175446e-01  8.716696e-01
# max    1.691741e+01   1.425306e+02    3.038243e+01  7.025525e+00
#
#        (collections_12_mths_ex_med,)  (delinq_2yrs,)  (delinq_amnt,)  ...  \
# count                   4.605410e+05    4.605410e+05    4.605410e+05  ...
# mean                   -1.999296e-14    9.389580e-15   -7.496327e-16  ...
# std                     1.000001e+00    1.000001e+00    1.000001e+00  ...
# min                    -1.211234e-01   -3.737692e-01   -1.815071e-02  ...
# 25%                    -1.211234e-01   -3.737692e-01   -1.815071e-02  ...
# 50%                    -1.211234e-01   -3.737692e-01   -1.815071e-02  ...
# 75%                    -1.211234e-01   -3.737692e-01   -1.815071e-02  ...
# max                     1.309155e+02    4.214538e+01    1.318908e+02  ...
#
#        (tax_liens,)  (tot_cur_bal,)  (total_acc,)  (total_bal_ex_mort,)  \
# count  4.605410e+05    4.605410e+05  4.605410e+05          4.605410e+05
# mean  -2.391354e-14   -1.129817e-16  2.167242e-14          3.145387e-16
# std    1.000001e+00    1.000001e+00  1.000001e+00          1.000001e+00
# min   -1.366871e-01   -9.014078e-01 -1.973622e+00         -1.055629e+00
# 25%   -1.366871e-01   -7.083070e-01 -7.399823e-01         -6.033212e-01
# 50%   -1.366871e-01   -3.883313e-01 -1.642840e-01         -2.565762e-01
# 75%   -1.366871e-01    4.410549e-01  5.758996e-01          2.731863e-01
# max    2.024282e+02    2.517700e+01  1.176090e+01          5.594216e+01
#
#        (total_bc_limit,)  (total_cu_tl,)  (total_rev_hi_lim,)   (MORTGAGE,)  \
# count       4.605410e+05    4.605410e+05         4.605410e+05  4.605410e+05
# mean        1.271174e-15    1.253828e-13        -7.387676e-16 -4.441019e-14
# std         1.000001e+00    1.000001e+00         1.000001e+00  1.000001e+00
# min        -9.861302e-01   -1.373566e+00        -8.891662e-01 -9.906655e-01
# 25%        -6.447970e-01   -6.214527e-02        -5.090448e-01 -9.906655e-01
# 50%        -3.082714e-01   -6.214527e-02        -2.387363e-01 -9.906655e-01
# 75%         2.926671e-01   -6.214527e-02         2.145937e-01  1.009422e+00
# max         3.555094e+01    8.780303e+01         2.806822e+02  1.009422e+00
#
#              (OWN,)       (RENT,)
# count  4.605410e+05  4.605410e+05
# mean  -3.780213e-14  1.841350e-14
# std    1.000001e+00  1.000001e+00
# min   -3.410606e-01 -8.173190e-01
# 25%   -3.410606e-01 -8.173190e-01
# 50%   -3.410606e-01 -8.173190e-01
# 75%   -3.410606e-01  1.223512e+00
# max    2.932031e+00  1.223512e+00
#
# [8 rows x 49 columns]

# %%
for col in df_ind_esc.columns:
    percentiles = df_ind_esc[col].quantile([0.01,0.99]).values
    df_ind_esc[col] = np.clip(df_ind_esc[col], percentiles[0], percentiles[1])

# %% [markdown]
# def cap_data(df):
#     for col in df.columns:
#         print("capping the ",col)
#         if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
#             percentiles = df[col].quantile([0.01,0.99]).values
#             df[col][df[col] <= percentiles[0]] = percentiles[0]
#             df[col][df[col] >= percentiles[1]] = percentiles[1]
#         else:
#             df[col]=df[col]
#     return df

# %%
df_ind_esc.describe()
# Out:
#        loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  \
# count    460541.000000       4.605410e+05            460541.000000
# mean          0.748266      -7.041427e-02                -0.008588
# std           0.434010       8.621307e-13                 0.961579
# min           0.000000      -7.041427e-02                -1.523188
# 25%           0.000000      -7.041427e-02                -0.572986
# 50%           1.000000      -7.041427e-02                -0.256252
# 75%           1.000000      -7.041427e-02                 0.377215
# max           1.000000      -7.041427e-02                 3.227820
#
#          (all_util,)  (annual_inc,)  (avg_cur_bal,)     (bc_util,)  \
# count  460541.000000  460541.000000   460541.000000  460541.000000
# mean        0.005580      -0.021869       -0.017908      -0.001363
# std         0.735791       0.626599        0.881822       0.997465
# min        -4.391856      -0.857487       -0.798574      -2.250694
# 25%         0.016959      -0.449147       -0.634011      -0.742218
# 50%         0.016959      -0.161796       -0.374148       0.130154
# 75%         0.016959       0.216297        0.317545       0.871670
# max         3.690971       2.636094        3.676630       1.424172
#
#        (collections_12_mths_ex_med,)  (delinq_2yrs,)  (delinq_amnt,)  ...  \
# count                  460541.000000   460541.000000    4.605410e+05  ...
# mean                       -0.010229       -0.024196   -1.815071e-02  ...
# std                         0.845143        0.823034    9.644726e-14  ...
# min                        -0.121123       -0.373769   -1.815071e-02  ...
# 25%                        -0.121123       -0.373769   -1.815071e-02  ...
# 50%                        -0.121123       -0.373769   -1.815071e-02  ...
# 75%                        -0.121123       -0.373769   -1.815071e-02  ...
# max                         6.430706        3.987169   -1.815071e-02  ...
#
#         (tax_liens,)  (tot_cur_bal,)   (total_acc,)  (total_bal_ex_mort,)  \
# count  460541.000000   460541.000000  460541.000000         460541.000000
# mean       -0.024388       -0.015059      -0.005312             -0.017559
# std         0.617246        0.911988       0.974900              0.881254
# min        -0.136687       -0.879416      -1.644651             -0.998027
# 25%        -0.136687       -0.708307      -0.739982             -0.603321
# 50%        -0.136687       -0.388331      -0.164284             -0.256576
# 75%        -0.136687        0.441055       0.575900              0.273186
# max         4.629547        3.378580       2.960936              3.887458
#
#        (total_bc_limit,)  (total_cu_tl,)  (total_rev_hi_lim,)   (MORTGAGE,)  \
# count      460541.000000   460541.000000        460541.000000  4.605410e+05
# mean           -0.013363       -0.042135            -0.022233 -4.440190e-14
# std             0.924031        0.514728             0.737688  1.000001e+00
# min            -0.986130       -1.373566            -0.810326 -9.906655e-01
# 25%            -0.644797       -0.062145            -0.509045 -9.906655e-01
# 50%            -0.308271       -0.062145            -0.238736 -9.906655e-01
# 75%             0.292667       -0.062145             0.214594  1.009422e+00
# max             3.826186        3.872116             3.371009  1.009422e+00
#
#              (OWN,)       (RENT,)
# count  4.605410e+05  4.605410e+05
# mean  -3.780213e-14  1.841350e-14
# std    1.000001e+00  1.000001e+00
# min   -3.410606e-01 -8.173190e-01
# 25%   -3.410606e-01 -8.173190e-01
# 50%   -3.410606e-01 -8.173190e-01
# 75%   -3.410606e-01  1.223512e+00
# max    2.932031e+00  1.223512e+00
#
# [8 rows x 49 columns]

# %% [markdown]
# ## 5.4. Visualization

# %%
df_ind.hist(figsize = (16, 20), bins = 150, xlabelsize = 8, ylabelsize = 8);

# %%
df_ind.corr()
# Out:
#                                 loan_acceptance  acc_now_delinq  \
# loan_acceptance                        1.000000       -0.005776
# acc_now_delinq                        -0.005776        1.000000
# acc_open_past_24mths                  -0.100671       -0.003052
# all_util                              -0.139275       -0.031050
# annual_inc                             0.046918        0.014104
# avg_cur_bal                            0.086341        0.016817
# bc_util                               -0.087397       -0.030187
# collections_12_mths_ex_med            -0.016250        0.017111
# delinq_2yrs                           -0.024632        0.127188
# delinq_amnt                           -0.001065        0.157997
# dti                                   -0.136539        0.004727
# emp_length                             0.028116        0.008641
# il_util                               -0.041811       -0.022325
# inq_fi                                -0.026625       -0.009395
# inq_last_12m                          -0.034146       -0.012584
# inq_last_6mths                        -0.055174       -0.004442
# installment                           -0.038518        0.004779
# int_rate                              -0.269034        0.024660
# loan_amnt                             -0.065125        0.001664
# max_bal_bc                             0.019562       -0.003759
# mo_sin_old_il_acct                     0.024502        0.016452
# mo_sin_rcnt_rev_tl_op                  0.049713        0.003016
# mort_acc                               0.086506        0.023644
# mths_since_last_delinq                 0.016896       -0.147896
# mths_since_recent_bc_dlq               0.014360       -0.115234
# mths_since_recent_inq                  0.052774        0.003911
# mths_since_recent_revol_delinq         0.015152       -0.124908
# num_actv_bc_tl                        -0.048342       -0.009425
# num_actv_rev_tl                       -0.083066       -0.003190
# num_bc_sats                           -0.011381       -0.005978
# num_bc_tl                              0.026396        0.013199
# num_il_tl                             -0.010876        0.009807
# num_op_rev_tl                         -0.036693        0.011933
# num_rev_accts                          0.012640        0.022690
# num_rev_tl_bal_gt_0                   -0.084209       -0.002317
# num_sats                              -0.034884        0.007666
# num_tl_120dpd_2m                      -0.000990        0.399903
# num_tl_30dpd                          -0.004060        0.805503
# num_tl_90g_dpd_24m                    -0.009445        0.060585
# num_tl_op_past_12m                    -0.084759       -0.007643
# open_acc                              -0.034664        0.017760
# open_act_il                           -0.038846        0.004785
# percent_bc_gt_75                      -0.090933       -0.026755
# revol_bal                              0.016929       -0.001244
# tax_liens                             -0.010676        0.005792
# tot_cur_bal                            0.076605        0.023965
# tot_hi_cred_lim                        0.084349        0.027568
# total_acc                              0.017159        0.026712
# total_bal_ex_mort                     -0.003437        0.011028
# total_bal_il                          -0.019708        0.009571
# total_bc_limit                         0.077837        0.004537
# total_cu_tl                            0.042634        0.002067
# total_rev_hi_lim                       0.055525        0.008662
# MORTGAGE                               0.076213        0.015809
# OWN                                   -0.007279        0.000382
# RENT                                  -0.073232       -0.016369
#
#                                 acc_open_past_24mths  all_util  annual_inc  \
# loan_acceptance                            -0.100671 -0.139275    0.046918
# acc_now_delinq                             -0.003052 -0.031050    0.014104
# acc_open_past_24mths                        1.000000 -0.050587    0.044414
# all_util                                   -0.050587  1.000000    0.000465
# annual_inc                                  0.044414  0.000465    1.000000
# avg_cur_bal                                -0.097565  0.087316    0.324151
# bc_util                                    -0.158689  0.598710   -0.006501
# collections_12_mths_ex_med                  0.010836 -0.021357   -0.005303
# delinq_2yrs                                -0.061258  0.015778    0.045026
# delinq_amnt                                -0.001576 -0.014624    0.006604
# dti                                         0.163943  0.258103   -0.187234
# emp_length                                  0.029391 -0.009536    0.089766
# il_util                                     0.191563  0.545313   -0.054736
# inq_fi                                      0.302980  0.057863    0.054739
# inq_last_12m                                0.398160  0.008144    0.065958
# inq_last_6mths                              0.256776 -0.056554    0.032773
# installment                                 0.017575  0.036680    0.328545
# int_rate                                    0.202972  0.225504   -0.083556
# loan_amnt                                   0.007892  0.019259    0.335544
# max_bal_bc                                 -0.099487  0.144788    0.303953
# mo_sin_old_il_acct                          0.000632  0.064501    0.116241
# mo_sin_rcnt_rev_tl_op                      -0.402260  0.108202    0.040123
# mort_acc                                    0.052426 -0.030147    0.221254
# mths_since_last_delinq                      0.128327  0.012882   -0.051572
# mths_since_recent_bc_dlq                    0.165626  0.016121   -0.053537
# mths_since_recent_inq                      -0.202253  0.028611   -0.040154
# mths_since_recent_revol_delinq              0.136097  0.031346   -0.043569
# num_actv_bc_tl                              0.205956 -0.018018    0.104094
# num_actv_rev_tl                             0.338356 -0.009230    0.067003
# num_bc_sats                                 0.273682 -0.213538    0.120119
# num_bc_tl                                   0.268125 -0.229822    0.127829
# num_il_tl                                   0.256756  0.262203    0.096025
# num_op_rev_tl                               0.450548 -0.251730    0.076491
# num_rev_accts                               0.378396 -0.234815    0.101923
# num_rev_tl_bal_gt_0                         0.330561  0.010809    0.067395
# num_sats                                    0.479475 -0.010270    0.127943
# num_tl_120dpd_2m                           -0.004761 -0.014400    0.004846
# num_tl_30dpd                               -0.002566 -0.022688    0.013904
# num_tl_90g_dpd_24m                         -0.037229  0.021158    0.009023
# num_tl_op_past_12m                          0.743238 -0.053138    0.047192
# open_acc                                    0.481435 -0.011714    0.128020
# open_act_il                                 0.147391  0.388442    0.054935
# percent_bc_gt_75                           -0.145555  0.497665   -0.021397
# revol_bal                                  -0.021212  0.115399    0.290690
# tax_liens                                   0.005319  0.003982    0.038101
# tot_cur_bal                                 0.072119  0.093768    0.409552
# tot_hi_cred_lim                             0.078130  0.015350    0.423652
# total_acc                                   0.426584 -0.003100    0.172420
# total_bal_ex_mort                           0.145682  0.307580    0.320943
# total_bal_il                                0.175949  0.304618    0.200867
# total_bc_limit                              0.028876 -0.291726    0.279124
# total_cu_tl                                 0.147286  0.058605    0.037992
# total_rev_hi_lim                            0.076003 -0.234262    0.281022
# MORTGAGE                                    0.051485  0.005193    0.146583
# OWN                                         0.002183 -0.051501   -0.026938
# RENT                                       -0.053894  0.029625   -0.132771
#
#                                 avg_cur_bal   bc_util  \
# loan_acceptance                    0.086341 -0.087397
# acc_now_delinq                     0.016817 -0.030187
# acc_open_past_24mths              -0.097565 -0.158689
# all_util                           0.087316  0.598710
# annual_inc                         0.324151 -0.006501
# avg_cur_bal                        1.000000  0.068699
# bc_util                            0.068699  1.000000
# collections_12_mths_ex_med        -0.013967 -0.032536
# delinq_2yrs                        0.049446 -0.011922
# delinq_amnt                        0.020000 -0.008622
# dti                               -0.132567  0.183170
# emp_length                         0.099951  0.025878
# il_util                           -0.019210 -0.054476
# inq_fi                             0.049534 -0.067329
# inq_last_12m                       0.030436 -0.108594
# inq_last_6mths                    -0.032793 -0.076838
# installment                        0.216037  0.068087
# int_rate                          -0.079240  0.235372
# loan_amnt                          0.238049  0.053804
# max_bal_bc                         0.273822  0.326384
# mo_sin_old_il_acct                 0.118597  0.045423
# mo_sin_rcnt_rev_tl_op              0.168829  0.117813
# mort_acc                           0.446528 -0.005661
# mths_since_last_delinq            -0.076245  0.011658
# mths_since_recent_bc_dlq          -0.063690  0.022203
# mths_since_recent_inq              0.001035  0.075487
# mths_since_recent_revol_delinq    -0.045030  0.023824
# num_actv_bc_tl                    -0.115697  0.069694
# num_actv_rev_tl                   -0.161580  0.113725
# num_bc_sats                       -0.119833 -0.182099
# num_bc_tl                         -0.047018 -0.177706
# num_il_tl                          0.039910  0.021007
# num_op_rev_tl                     -0.194371 -0.153899
# num_rev_accts                     -0.079877 -0.148569
# num_rev_tl_bal_gt_0               -0.160527  0.121341
# num_sats                          -0.115232 -0.103536
# num_tl_120dpd_2m                   0.005154 -0.011776
# num_tl_30dpd                       0.018066 -0.022991
# num_tl_90g_dpd_24m                 0.011711 -0.013869
# num_tl_op_past_12m                -0.072068 -0.170073
# open_acc                          -0.115616 -0.104186
# open_act_il                       -0.057039  0.069616
# percent_bc_gt_75                   0.056710  0.839227
# revol_bal                          0.290453  0.148850
# tax_liens                          0.002477 -0.009668
# tot_cur_bal                        0.837956  0.039757
# tot_hi_cred_lim                    0.801869 -0.011966
# total_acc                          0.049047 -0.091544
# total_bal_ex_mort                  0.288167  0.083506
# total_bal_il                       0.178986  0.037844
# total_bc_limit                     0.153431 -0.239669
# total_cu_tl                        0.052915 -0.001498
# total_rev_hi_lim                   0.209646 -0.161316
# MORTGAGE                           0.443242  0.015698
# OWN                               -0.058427 -0.041713
# RENT                              -0.415841  0.009995
#
#                                 collections_12_mths_ex_med  delinq_2yrs  \
# loan_acceptance                                  -0.016250    -0.024632
# acc_now_delinq                                    0.017111     0.127188
# acc_open_past_24mths                              0.010836    -0.061258
# all_util                                         -0.021357     0.015778
# annual_inc                                       -0.005303     0.045026
# avg_cur_bal                                      -0.013967     0.049446
# bc_util                                          -0.032536    -0.011922
# collections_12_mths_ex_med                        1.000000     0.059855
# delinq_2yrs                                       0.059855     1.000000
# delinq_amnt                                       0.003789     0.030822
# dti                                              -0.008091    -0.018966
# emp_length                                       -0.006424     0.027986
# il_util                                          -0.003197    -0.008622
# inq_fi                                            0.008782     0.031987
# inq_last_12m                                      0.017002     0.028072
# inq_last_6mths                                    0.013022     0.030506
# installment                                      -0.016150     0.003339
# int_rate                                          0.018452     0.049393
# loan_amnt                                        -0.019680    -0.006174
# max_bal_bc                                       -0.033705    -0.057337
# mo_sin_old_il_acct                                0.009279     0.081902
# mo_sin_rcnt_rev_tl_op                            -0.006072     0.037084
# mort_acc                                         -0.009356     0.076867
# mths_since_last_delinq                           -0.041324    -0.559075
# mths_since_recent_bc_dlq                         -0.009174    -0.485653
# mths_since_recent_inq                            -0.009544    -0.027222
# mths_since_recent_revol_delinq                   -0.010514    -0.512178
# num_actv_bc_tl                                   -0.010942    -0.050231
# num_actv_rev_tl                                  -0.000652    -0.011778
# num_bc_sats                                      -0.001745    -0.034815
# num_bc_tl                                        -0.009251     0.032803
# num_il_tl                                         0.009254     0.080671
# num_op_rev_tl                                     0.003178     0.000515
# num_rev_accts                                    -0.001085     0.077313
# num_rev_tl_bal_gt_0                              -0.005580    -0.015023
# num_sats                                          0.005492     0.039848
# num_tl_120dpd_2m                                  0.002820     0.049414
# num_tl_30dpd                                      0.000089     0.106489
# num_tl_90g_dpd_24m                                0.088176     0.655243
# num_tl_op_past_12m                                0.007156    -0.029390
# open_acc                                          0.005872     0.042845
# open_act_il                                       0.014363     0.052876
# percent_bc_gt_75                                 -0.032722    -0.010628
# revol_bal                                        -0.025602    -0.034165
# tax_liens                                         0.012601     0.012017
# tot_cur_bal                                      -0.012403     0.059919
# tot_hi_cred_lim                                  -0.011514     0.062133
# total_acc                                         0.006716     0.118060
# total_bal_ex_mort                                -0.014383     0.029097
# total_bal_il                                     -0.006782     0.047778
# total_bc_limit                                   -0.028160    -0.077257
# total_cu_tl                                      -0.007739     0.018986
# total_rev_hi_lim                                 -0.019871    -0.045702
# MORTGAGE                                         -0.007656     0.046713
# OWN                                               0.001342    -0.005588
# RENT                                              0.006976    -0.044181
#
#                                 delinq_amnt  ...  tot_hi_cred_lim  total_acc  \
# loan_acceptance                   -0.001065  ...         0.084349   0.017159
# acc_now_delinq                     0.157997  ...         0.027568   0.026712
# acc_open_past_24mths              -0.001576  ...         0.078130   0.426584
# all_util                          -0.014624  ...         0.015350  -0.003100
# annual_inc                         0.006604  ...         0.423652   0.172420
# avg_cur_bal                        0.020000  ...         0.801869   0.049047
# bc_util                           -0.008622  ...        -0.011966  -0.091544
# collections_12_mths_ex_med         0.003789  ...        -0.011514   0.006716
# delinq_2yrs                        0.030822  ...         0.062133   0.118060
# delinq_amnt                        1.000000  ...         0.019062   0.007090
# dti                               -0.005684  ...        -0.003070   0.207732
# emp_length                         0.003247  ...         0.127401   0.098304
# il_util                           -0.025636  ...        -0.026331   0.108273
# inq_fi                            -0.002172  ...         0.086840   0.174757
# inq_last_12m                      -0.004270  ...         0.097205   0.220878
# inq_last_6mths                     0.004327  ...         0.016517   0.146050
# installment                        0.000254  ...         0.320206   0.184720
# int_rate                           0.008596  ...        -0.112992  -0.050519
# loan_amnt                         -0.000586  ...         0.349665   0.207718
# max_bal_bc                        -0.007100  ...         0.377935   0.123877
# mo_sin_old_il_acct                 0.003088  ...         0.173347   0.334365
# mo_sin_rcnt_rev_tl_op              0.004231  ...         0.040266  -0.160755
# mort_acc                           0.016574  ...         0.517803   0.364655
# mths_since_last_delinq            -0.034072  ...        -0.103421  -0.042646
# mths_since_recent_bc_dlq          -0.002390  ...        -0.084905   0.010447
# mths_since_recent_inq             -0.001429  ...        -0.038708  -0.118534
# mths_since_recent_revol_delinq    -0.000878  ...        -0.082730  -0.016672
# num_actv_bc_tl                    -0.001978  ...         0.123498   0.271206
# num_actv_rev_tl                   -0.000485  ...         0.109077   0.380897
# num_bc_sats                        0.001673  ...         0.154591   0.369920
# num_bc_tl                          0.003318  ...         0.170789   0.623957
# num_il_tl                          0.000714  ...         0.176934   0.669499
# num_op_rev_tl                      0.000662  ...         0.138907   0.540140
# num_rev_accts                      0.004732  ...         0.174263   0.760995
# num_rev_tl_bal_gt_0               -0.001462  ...         0.111642   0.380490
# num_sats                          -0.001408  ...         0.272665   0.684159
# num_tl_120dpd_2m                   0.255535  ...         0.006336   0.012592
# num_tl_30dpd                       0.051730  ...         0.029174   0.021313
# num_tl_90g_dpd_24m                 0.040313  ...         0.005938   0.070507
# num_tl_op_past_12m                -0.000674  ...         0.059400   0.320179
# open_acc                           0.002148  ...         0.272187   0.688960
# open_act_il                       -0.011063  ...         0.120108   0.352294
# percent_bc_gt_75                  -0.008139  ...        -0.016880  -0.083399
# revol_bal                         -0.001479  ...         0.469071   0.175555
# tax_liens                          0.002162  ...        -0.002250  -0.023051
# tot_cur_bal                        0.019796  ...         0.977464   0.300130
# tot_hi_cred_lim                    0.019062  ...         1.000000   0.321108
# total_acc                          0.007090  ...         0.321108   1.000000
# total_bal_ex_mort                  0.002378  ...         0.504369   0.420493
# total_bal_il                      -0.008025  ...         0.337060   0.399570
# total_bc_limit                     0.000317  ...         0.401187   0.250724
# total_cu_tl                       -0.005367  ...         0.103480   0.283672
# total_rev_hi_lim                   0.000880  ...         0.481928   0.266690
# MORTGAGE                          -0.000372  ...         0.490511   0.193187
# OWN                               -0.000834  ...        -0.056630  -0.008381
# RENT                               0.000900  ...        -0.465190  -0.191889
#
#                                 total_bal_ex_mort  total_bal_il  \
# loan_acceptance                         -0.003437     -0.019708
# acc_now_delinq                           0.011028      0.009571
# acc_open_past_24mths                     0.145682      0.175949
# all_util                                 0.307580      0.304618
# annual_inc                               0.320943      0.200867
# avg_cur_bal                              0.288167      0.178986
# bc_util                                  0.083506      0.037844
# collections_12_mths_ex_med              -0.014383     -0.006782
# delinq_2yrs                              0.029097      0.047778
# delinq_amnt                              0.002378     -0.008025
# dti                                      0.280129      0.270994
# emp_length                               0.007394     -0.007880
# il_util                                  0.228947      0.312930
# inq_fi                                   0.089573      0.126949
# inq_last_12m                             0.104119      0.136854
# inq_last_6mths                           0.030919      0.046770
# installment                              0.268540      0.143308
# int_rate                                -0.014978      0.031234
# loan_amnt                                0.287940      0.157080
# max_bal_bc                               0.341178      0.102194
# mo_sin_old_il_acct                       0.191150      0.202199
# mo_sin_rcnt_rev_tl_op                    0.026343     -0.010251
# mort_acc                                 0.131860      0.069556
# mths_since_last_delinq                  -0.041113     -0.009955
# mths_since_recent_bc_dlq                -0.036463      0.013591
# mths_since_recent_inq                   -0.044428     -0.067424
# mths_since_recent_revol_delinq          -0.034904      0.006734
# num_actv_bc_tl                           0.139993      0.027319
# num_actv_rev_tl                          0.128324      0.024367
# num_bc_sats                              0.128278      0.030019
# num_bc_tl                                0.113877      0.034321
# num_il_tl                                0.514925      0.583453
# num_op_rev_tl                            0.121742      0.030062
# num_rev_accts                            0.112195      0.038494
# num_rev_tl_bal_gt_0                      0.134590      0.027214
# num_sats                                 0.399492      0.329118
# num_tl_120dpd_2m                         0.005028      0.008054
# num_tl_30dpd                             0.010957      0.010961
# num_tl_90g_dpd_24m                       0.010148      0.028547
# num_tl_op_past_12m                       0.105862      0.143531
# open_acc                                 0.398712      0.327230
# open_act_il                              0.478968      0.558016
# percent_bc_gt_75                         0.062811      0.025069
# revol_bal                                0.508731      0.079914
# tax_liens                               -0.006296      0.007446
# tot_cur_bal                              0.513948      0.366133
# tot_hi_cred_lim                          0.504369      0.337060
# total_acc                                0.420493      0.399570
# total_bal_ex_mort                        1.000000      0.895312
# total_bal_il                             0.895312      1.000000
# total_bc_limit                           0.288080      0.071059
# total_cu_tl                              0.102411      0.099178
# total_rev_hi_lim                         0.425382      0.077952
# MORTGAGE                                 0.110564      0.068509
# OWN                                     -0.023795     -0.031609
# RENT                                    -0.097980     -0.049148
#
#                                 total_bc_limit  total_cu_tl  total_rev_hi_lim  \
# loan_acceptance                       0.077837     0.042634          0.055525
# acc_now_delinq                        0.004537     0.002067          0.008662
# acc_open_past_24mths                  0.028876     0.147286          0.076003
# all_util                             -0.291726     0.058605         -0.234262
# annual_inc                            0.279124     0.037992          0.281022
# avg_cur_bal                           0.153431     0.052915          0.209646
# bc_util                              -0.239669    -0.001498         -0.161316
# collections_12_mths_ex_med           -0.028160    -0.007739         -0.019871
# delinq_2yrs                          -0.077257     0.018986         -0.045702
# delinq_amnt                           0.000317    -0.005367          0.000880
# dti                                   0.028558     0.127853          0.064954
# emp_length                            0.058957     0.079722          0.077044
# il_util                              -0.106108     0.021353         -0.096209
# inq_fi                               -0.050064     0.087822         -0.031778
# inq_last_12m                         -0.001335     0.068319          0.022343
# inq_last_6mths                       -0.018301     0.022059          0.004237
# installment                           0.361732     0.046710          0.304535
# int_rate                             -0.233540     0.022372         -0.158196
# loan_amnt                             0.392158     0.051438          0.327949
# max_bal_bc                            0.563696    -0.027562          0.474796
# mo_sin_old_il_acct                    0.079776     0.110839          0.081102
# mo_sin_rcnt_rev_tl_op                -0.004393    -0.015552         -0.034341
# mort_acc                              0.192676     0.161953          0.201439
# mths_since_last_delinq               -0.026948    -0.015323         -0.027654
# mths_since_recent_bc_dlq             -0.092928     0.005475         -0.066570
# mths_since_recent_inq                 0.011889    -0.037688         -0.009153
# mths_since_recent_revol_delinq       -0.076312    -0.011081         -0.074437
# num_actv_bc_tl                        0.461938    -0.081929          0.322670
# num_actv_rev_tl                       0.267571     0.015729          0.297038
# num_bc_sats                           0.575745    -0.069807          0.407284
# num_bc_tl                             0.456154    -0.002848          0.340900
# num_il_tl                            -0.022294     0.297796         -0.002699
# num_op_rev_tl                         0.399492     0.046902          0.397454
# num_rev_accts                         0.332908     0.108882          0.338485
# num_rev_tl_bal_gt_0                   0.268919     0.027402          0.297811
# num_sats                              0.343836     0.090299          0.343798
# num_tl_120dpd_2m                     -0.003039     0.000052         -0.001650
# num_tl_30dpd                          0.008615     0.004938          0.012532
# num_tl_90g_dpd_24m                   -0.060908    -0.010652         -0.046003
# num_tl_op_past_12m                    0.018547     0.104040          0.055294
# open_acc                              0.341779     0.089463          0.343526
# open_act_il                          -0.032707     0.070751         -0.029898
# percent_bc_gt_75                     -0.204464     0.006105         -0.136965
# revol_bal                             0.499325     0.032501          0.820823
# tax_liens                            -0.028351    -0.003363         -0.020927
# tot_cur_bal                           0.324725     0.100804          0.396554
# tot_hi_cred_lim                       0.401187     0.103480          0.481928
# total_acc                             0.250724     0.283672          0.266690
# total_bal_ex_mort                     0.288080     0.102411          0.425382
# total_bal_il                          0.071059     0.099178          0.077952
# total_bc_limit                        1.000000    -0.041568          0.713384
# total_cu_tl                          -0.041568     1.000000          0.034576
# total_rev_hi_lim                      0.713384     0.034576          1.000000
# MORTGAGE                              0.127185     0.103743          0.147797
# OWN                                   0.023421    -0.010346          0.028370
# RENT                                 -0.144375    -0.099836         -0.168492
#
#                                 MORTGAGE       OWN      RENT
# loan_acceptance                 0.076213 -0.007279 -0.073232
# acc_now_delinq                  0.015809  0.000382 -0.016369
# acc_open_past_24mths            0.051485  0.002183 -0.053894
# all_util                        0.005193 -0.051501  0.029625
# annual_inc                      0.146583 -0.026938 -0.132771
# avg_cur_bal                     0.443242 -0.058427 -0.415841
# bc_util                         0.015698 -0.041713  0.009995
# collections_12_mths_ex_med     -0.007656  0.001342  0.006976
# delinq_2yrs                     0.046713 -0.005588 -0.044181
# delinq_amnt                    -0.000372 -0.000834  0.000900
# dti                            -0.016633  0.026125  0.000679
# emp_length                      0.173381 -0.007643 -0.172145
# il_util                        -0.033666 -0.007187  0.039495
# inq_fi                          0.083934 -0.001104 -0.085692
# inq_last_12m                    0.083657 -0.007011 -0.081404
# inq_last_6mths                  0.018076  0.004024 -0.020951
# installment                     0.154535 -0.014240 -0.148797
# int_rate                       -0.059445  0.010661  0.054008
# loan_amnt                       0.181979 -0.018460 -0.174169
# max_bal_bc                      0.123096 -0.006746 -0.122217
# mo_sin_old_il_acct              0.147721 -0.012634 -0.143222
# mo_sin_rcnt_rev_tl_op           0.015628 -0.004458 -0.013160
# mort_acc                        0.467101 -0.059821 -0.439312
# mths_since_last_delinq         -0.053030  0.005762  0.051074
# mths_since_recent_bc_dlq       -0.039523  0.000433  0.040627
# mths_since_recent_inq          -0.041521 -0.002685  0.044210
# mths_since_recent_revol_delinq -0.039349 -0.003879  0.043113
# num_actv_bc_tl                  0.033719  0.003524 -0.036602
# num_actv_rev_tl                 0.063039  0.007262 -0.068847
# num_bc_sats                     0.043770  0.015852 -0.054547
# num_bc_tl                       0.086244  0.027381 -0.105069
# num_il_tl                       0.058191 -0.032299 -0.039234
# num_op_rev_tl                   0.065740  0.028841 -0.085060
# num_rev_accts                   0.113580  0.032101 -0.135902
# num_rev_tl_bal_gt_0             0.062772  0.007924 -0.068987
# num_sats                        0.112324 -0.006636 -0.110472
# num_tl_120dpd_2m                0.001788 -0.003464  0.000340
# num_tl_30dpd                    0.018128  0.002286 -0.019921
# num_tl_90g_dpd_24m             -0.000082 -0.007653  0.004858
# num_tl_op_past_12m              0.035640  0.003895 -0.038803
# open_acc                        0.113310 -0.006757 -0.111403
# open_act_il                    -0.015749 -0.030928  0.037235
# percent_bc_gt_75                0.008095 -0.033214  0.012457
# revol_bal                       0.146497  0.010928 -0.156290
# tax_liens                      -0.000245  0.003244 -0.001772
# tot_cur_bal                     0.492157 -0.063508 -0.462582
# tot_hi_cred_lim                 0.490511 -0.056630 -0.465190
# total_acc                       0.193187 -0.008381 -0.191889
# total_bal_ex_mort               0.110564 -0.023795 -0.097980
# total_bal_il                    0.068509 -0.031609 -0.049148
# total_bc_limit                  0.127185  0.023421 -0.144375
# total_cu_tl                     0.103743 -0.010346 -0.099836
# total_rev_hi_lim                0.147797  0.028370 -0.168492
# MORTGAGE                        1.000000 -0.337877 -0.809690
# OWN                            -0.337877  1.000000 -0.278755
# RENT                           -0.809690 -0.278755  1.000000
#
# [56 rows x 56 columns]

# %%
    # Generamos una mask para el triángulo superior
mask = np.triu(np.ones_like(df_ind.corr(), dtype = bool))
            # np.triu(): Devuelve una copia de una matriz con los elementos debajo de la diagonal "K"-ésima en ceros.
            # np.ones_like(): Devuelve un array de unos con el mismo tamaño y tipo que el array principal (data.corr())
    
    
    # Generamos el tamaño de la figura
f, ax = plt.subplots(figsize=(25, 25))

    # Dibujamos el mapa de calor
sn.heatmap(df_ind.corr(), annot = True, fmt = '.1f', mask = mask, square = True, linewidths = .5, cmap = "viridis");
            # annot = True/False: si queremos los valores de las correlaciones ponemos True, por defecto viene False
            # fmt '.Nf' es para decir cuántos decimales queremos en cada cuadrado
            # mask = ...: Si añadimos una mask, los datos no se mostrarán en las celdas donde sea True
            # square = True: es para obtener cuadrados, es decir 1:1
            # linewidht = N: es el ancho de la linea entre cuadrados
            # cmap = "": tema que queremos escoger

# %%
data_pairplot = df_ind.loc[:,['int_rate','loan_amnt','tot_cur_bal','total_bc_limit']] #,
sn.pairplot(data_pairplot, palette = "viridis");  #

# %%
sn.jointplot(x = 'int_rate', y = 'loan_amnt', data = mini_df_ind, kind = 'reg')
sn.set(rc={'figure.figsize':(25,25)})

# %% [markdown]
# <a name= 'sixth-bullet'></a>
#
# ## 6. Dataframes convertion

# %%
df_ind_esc.to_csv('BB.DD_MODELOS.csv')

# %%
#Dataframe escalado, sin valores nulos (cambiados por la mediana) y con 56 variables (PARA INDIVIDUAL)
df_ind_esc.head(5)
# Out:
#    loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  (all_util,)  \
# 0                1          -0.070414                 1.010683    -4.391856
# 1                1          -0.070414                -0.889720     2.588767
# 2                1          -0.070414                 2.594353    -3.840754
# 3                1          -0.070414                 0.693949    -4.391856
# 4                1          -0.070414                 0.060482     3.690971
#
#    (annual_inc,)  (avg_cur_bal,)  (bc_util,)  (collections_12_mths_ex_med,)  \
# 0       1.169092        0.632931   -1.756350                      -0.121123
# 1      -0.388652       -0.712121    1.344204                      -0.121123
# 2       0.518772        0.083906   -1.236562                      -0.121123
# 3      -0.358722       -0.783204   -1.443750                      -0.121123
# 4      -0.010558        1.173048    1.020700                      -0.121123
#
#    (delinq_2yrs,)  (delinq_amnt,)  ...  (tax_liens,)  (tot_cur_bal,)  \
# 0       -0.373769       -0.018151  ...     -0.136687        1.966093
# 1       -0.373769       -0.018151  ...     -0.136687       -0.865215
# 2       -0.373769       -0.018151  ...     -0.136687        0.889188
# 3       -0.373769       -0.018151  ...     -0.136687       -0.830447
# 4        0.716465       -0.018151  ...     -0.136687       -0.074671
#
#    (total_acc,)  (total_bal_ex_mort,)  (total_bc_limit,)  (total_cu_tl,)  \
# 0      1.645054              1.082435           0.364780        3.872116
# 1     -1.644651             -0.937178          -0.813060       -1.373566
# 2      0.082444             -0.081508           3.037755        3.872116
# 3     -0.411012             -0.823391          -0.082319       -1.373566
# 4     -1.315681             -0.468803          -0.841905       -1.373566
#
#    (total_rev_hi_lim,)  (MORTGAGE,)    (OWN,)   (RENT,)
# 0             0.169542    -0.990665  2.932031 -0.817319
# 1            -0.787800    -0.990665 -0.341061  1.223512
# 2             1.523901     1.009422 -0.341061 -0.817319
# 3            -0.081056    -0.990665 -0.341061  1.223512
# 4            -0.804695     1.009422 -0.341061 -0.817319
#
# [5 rows x 49 columns]

# %%
df_ind_esc.shape
# Out:
# (460541, 49)

# %%
#Dataframe sin escalar y con valores nulos para individuales
df_ind.head(5)
# Out:
#     loan_acceptance  acc_now_delinq  acc_open_past_24mths  all_util  \
# 8                 1             0.0                   8.0      36.0
# 10                1             0.0                   2.0      74.0
# 24                1             0.0                  13.0      39.0
# 42                1             0.0                   7.0      32.0
# 91                1             0.0                   5.0      83.0
#
#     annual_inc  avg_cur_bal  bc_util  collections_12_mths_ex_med  delinq_2yrs  \
# 8     153000.0      23302.0     13.6                         0.0          0.0
# 10     50000.0       1863.0     98.9                         0.0          0.0
# 24    110000.0      14551.0     27.9                         0.0          0.0
# 42     51979.0        730.0     22.2                         0.0          0.0
# 91     75000.0      31911.0     90.0                         0.0          1.0
#
#     delinq_amnt  ...  tax_liens  tot_cur_bal  total_acc  total_bal_ex_mort  \
# 8           0.0  ...        0.0     442731.0       46.0           100865.0
# 10          0.0  ...        0.0       5588.0        5.0             5588.0
# 24          0.0  ...        0.0     276461.0       27.0            45955.0
# 42          0.0  ...        0.0      10956.0       21.0            10956.0
# 91          0.0  ...        0.0     127645.0       10.0            27684.0
#
#     total_bc_limit  total_cu_tl  total_rev_hi_lim  MORTGAGE  OWN  RENT
# 8          28100.0          6.0           37600.0         0    1     0
# 10          3600.0          0.0            3600.0         0    0     1
# 24         83700.0          8.0           85700.0         1    0     0
# 42         18800.0          0.0           28700.0         0    0     1
# 91          3000.0          0.0            3000.0         1    0     0
#
# [5 rows x 49 columns]

# %%
#Con 5000 observaciones (sin escalar y con nan)
mini_df_ind.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c16aab29a343> in <module>
#       1 #Con 5000 observaciones (sin escalar y con nan)
# ----> 2 mini_df_ind.head(5)
#
# NameError: name 'mini_df_ind' is not defined

# %%
#Dataframe escalado, sin valores nulos (cambiados por la mediana) y con 56 variables (PARA INDIVIDUAL)
df_ind_esc.head(5)
# Out:
#    loan_acceptance  (acc_now_delinq,)  (acc_open_past_24mths,)  (all_util,)  \
# 0                1          -0.070414                 1.010683    -4.391856
# 1                1          -0.070414                -0.889720     2.588767
# 2                1          -0.070414                 2.594353    -3.840754
# 3                1          -0.070414                 0.693949    -4.391856
# 4                1          -0.070414                 0.060482     3.690971
#
#    (annual_inc,)  (avg_cur_bal,)  (bc_util,)  (collections_12_mths_ex_med,)  \
# 0       1.169092        0.632931   -1.756350                      -0.121123
# 1      -0.388652       -0.712121    1.344204                      -0.121123
# 2       0.518772        0.083906   -1.236562                      -0.121123
# 3      -0.358722       -0.783204   -1.443750                      -0.121123
# 4      -0.010558        1.173048    1.020700                      -0.121123
#
#    (delinq_2yrs,)  (delinq_amnt,)  ...  (tax_liens,)  (tot_cur_bal,)  \
# 0       -0.373769       -0.018151  ...     -0.136687        1.966093
# 1       -0.373769       -0.018151  ...     -0.136687       -0.865215
# 2       -0.373769       -0.018151  ...     -0.136687        0.889188
# 3       -0.373769       -0.018151  ...     -0.136687       -0.830447
# 4        0.716465       -0.018151  ...     -0.136687       -0.074671
#
#    (total_acc,)  (total_bal_ex_mort,)  (total_bc_limit,)  (total_cu_tl,)  \
# 0      1.645054              1.082435           0.364780        3.872116
# 1     -1.644651             -0.937178          -0.813060       -1.373566
# 2      0.082444             -0.081508           3.037755        3.872116
# 3     -0.411012             -0.823391          -0.082319       -1.373566
# 4     -1.315681             -0.468803          -0.841905       -1.373566
#
#    (total_rev_hi_lim,)  (MORTGAGE,)    (OWN,)   (RENT,)
# 0             0.169542    -0.990665  2.932031 -0.817319
# 1            -0.787800    -0.990665 -0.341061  1.223512
# 2             1.523901     1.009422 -0.341061 -0.817319
# 3            -0.081056    -0.990665 -0.341061  1.223512
# 4            -0.804695     1.009422 -0.341061 -0.817319
#
# [5 rows x 49 columns]

# %%
df_ind_esc_50k = df_ind_esc.iloc[0:50000,]
df_ind_esc_50k.head(5)
# Out:
#   loan_acceptance acc_now_delinq acc_open_past_24mths  all_util annual_inc  \
# 0        0.580021      -0.070414             1.010683 -4.391856   1.169092
# 1        0.580021      -0.070414            -0.889720  2.588767  -0.388652
# 2        0.580021      -0.070414             2.594353 -3.840754   0.518772
# 3        0.580021      -0.070414             0.693949 -4.391856  -0.358722
# 4        0.580021      -0.070414             0.060482  3.690971  -0.010558
#
#   avg_cur_bal   bc_util collections_12_mths_ex_med delinq_2yrs delinq_amnt  \
# 0    0.632931 -1.756350                  -0.121123   -0.373769   -0.018151
# 1   -0.712121  1.344204                  -0.121123   -0.373769   -0.018151
# 2    0.083906 -1.236562                  -0.121123   -0.373769   -0.018151
# 3   -0.783204 -1.443750                  -0.121123   -0.373769   -0.018151
# 4    1.173048  1.020700                  -0.121123    0.716465   -0.018151
#
#    ... tot_hi_cred_lim total_acc total_bal_ex_mort total_bal_il  \
# 0  ...        2.060833  1.645054          1.082435     3.478613
# 1  ...       -0.934063 -1.644651         -0.937178    -1.840454
# 2  ...        1.037182  0.082444         -0.081508    -0.285265
# 3  ...       -0.787045 -0.411012         -0.823391    -1.813276
# 4  ...       -0.000715 -1.315681         -0.468803    -0.076333
#
#   total_bc_limit total_cu_tl total_rev_hi_lim  MORTGAGE       OWN      RENT
# 0       0.364780    3.872116         0.169542 -0.990665  2.932031 -0.817319
# 1      -0.813060   -1.373566        -0.787800 -0.990665 -0.341061  1.223512
# 2       3.037755    3.872116         1.523901  1.009422 -0.341061 -0.817319
# 3      -0.082319   -1.373566        -0.081056 -0.990665 -0.341061  1.223512
# 4      -0.841905   -1.373566        -0.804695  1.009422 -0.341061 -0.817319
#
# [5 rows x 56 columns]

# %%
df_ind_esc_50k.to_csv('50k_ind.csv')
